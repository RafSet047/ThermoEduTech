# %%
from data_wrapper import DataWrapper
import pandas as pd
import numpy as np

# %%
df = DataWrapper("dataset/data_small.csv")

# %%
df.head()
# Out:
#          Date      Time           Classroom Type Classroom Category  Room No  \
# 0  2023-02-08  07:34:34  Container No Insulation          Temporary        1
# 1  2023-02-08  07:57:34  Container No Insulation          Temporary        1
# 2  2023-02-08  08:20:29  Container No Insulation          Temporary        1
# 3  2023-02-08  08:30:10  Container No Insulation          Temporary        1
# 4  2023-02-08  08:46:21  Container No Insulation          Temporary        1
#
#    Device Code  School No  Grade  Measured T  Measured RH  Measured CO2  \
# 0            3          1      3        20.8         68.9           NaN
# 1            3          1      3        22.0         69.1           NaN
# 2            3          1      3        23.3         68.8           NaN
# 3            1          1      3        22.7         61.2           NaN
# 4            3          1      3        24.4         62.9           NaN
#
# ...
